# %% [markdown]
# ## COLA ✅

# %%
import pandas
import glob

data = []
for fn in glob.glob('/global/cscratch1/sd/haoyan/glue_eval/cola*/eval*.txt'):
    with open(fn) as f:
        contents = dict(map(lambda x: x.strip().split(' = '), filter(str.strip, f.readlines())))
        contents['fn'] = fn.split('/')[-2]
        data.append(contents)
d = pandas.DataFrame(data)

cased = d.loc[d.fn.apply(lambda x: '_cased_' in x)].sort_values(['eval_matthews_correlation'], ascending=False)
display(cased)

uncased = d.loc[d.fn.apply(lambda x: '_uncased_' in x)].sort_values(['eval_matthews_correlation'], ascending=False)
display(uncased)
# Out:
#              eval_loss eval_matthews_correlation epoch  \
# 1   0.8240000009536743       0.38221460495175935   7.0
# 15  1.2216286659240723       0.36250098253722524   6.0
# 4   1.3367689847946167        0.3604765725932801   8.0
# 13  1.0741394758224487        0.3520719211856073   8.0
# 6   1.3287327289581299        0.3319931000006738  10.0
# 11  1.1383765935897827        0.3297402781477889   8.0
# 9   1.0281596183776855        0.3237326020252071   5.0
# 3   0.8787429928779602       0.31270242586873276   8.0
# 0   1.4673539400100708       0.28891422810003087   8.0
# 8   0.6298601031303406                       0.0   8.0
#
#                          fn
# 1    cola_cased_bs64_epoch7
# 15   cola_cased_bs64_epoch6
# 4    cola_cased_bs64_epoch8
# 13   cola_cased_bs72_epoch8
# 6   cola_cased_bs64_epoch10
# 11  cola_cased_bs128_epoch8
# 9    cola_cased_bs64_epoch5
# 3    cola_cased_bs32_epoch8
# 0    cola_cased_bs16_epoch8
# 8     cola_cased_bs8_epoch8
# ...

# %%
fetch = cased.iloc[0]['fn']
targetdir = 'submission/matbert-base-cased'
targetfn = f'{targetdir}/CoLA.tsv'

# !mkdir -p {targetdir}
print(f'Copying results from {fetch}')
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_cola.txt {targetfn}
# !sed -i 's/unacceptable/0/g' {targetfn}
# !sed -i 's/acceptable/1/g' {targetfn}
# !wc -l {targetfn}

fetch = uncased.iloc[0]['fn']
targetdir = 'submission/matbert-base-uncased'
targetfn = f'{targetdir}/CoLA.tsv'

# !mkdir -p {targetdir}
print(f'Copying results from {fetch}')
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_cola.txt {targetfn}
# !sed -i 's/unacceptable/0/g' {targetfn}
# !sed -i 's/acceptable/1/g' {targetfn}
# !wc -l {targetfn}
# Out:
# Copying results from cola_cased_bs64_epoch7
# 1064 submission/matbert-base-cased/CoLA.tsv
# Copying results from cola_uncased_bs64_epoch9
# 1064 submission/matbert-base-uncased/CoLA.tsv

# %% [markdown]
# ## MRPC ✅

# %%
import pandas
import glob
from IPython.display import display

data = []
for fn in glob.glob('/global/cscratch1/sd/haoyan/glue_eval/mrpc*/eval*.txt'):
    with open(fn) as f:
        contents = dict(map(lambda x: x.strip().split(' = '), filter(str.strip, f.readlines())))
        contents['fn'] = fn.split('/')[-2]
        data.append(contents)
d = pandas.DataFrame(data)

cased = d.loc[d.fn.apply(lambda x: '_cased_' in x)].sort_values(['eval_combined_score'], ascending=False)
display(cased)

uncased = d.loc[d.fn.apply(lambda x: '_uncased_' in x)].sort_values(['eval_combined_score'], ascending=False)
display(uncased)
# Out:
#              eval_loss       eval_accuracy             eval_f1  \
# 0  0.33319756388664246  0.8602941176470589  0.8980322003577819
# 3   0.3766270875930786  0.8504901960784313  0.8957264957264958
# 4   0.7050721645355225  0.8431372549019608  0.8873239436619718
# 1    1.138953447341919  0.8357843137254902  0.8830715532286212
#
#   eval_combined_score epoch                      fn
# 0  0.8791631590024204   5.0   mrpc_cased_bs4_epoch5
# 3  0.8731083459024636   5.0   mrpc_cased_bs8_epoch5
# 4  0.8652305992819662   5.0  mrpc_cased_bs16_epoch5
# 1  0.8594279334770557   5.0   mrpc_cased_bs2_epoch5
#             eval_loss       eval_accuracy             eval_f1  \
# 2  0.6017373204231262  0.8774509803921569  0.9134948096885814
# 5  0.7946187853813171  0.8676470588235294   0.906896551724138
# 6  0.5621910691261292  0.8529411764705882   0.896551724137931
# 7  0.5914668440818787  0.8431372549019608  0.8877192982456141
#
#   eval_combined_score epoch                        fn
# ...

# %%
fetch = cased.iloc[0]['fn']
targetdir = 'submission/matbert-base-cased'
targetfn = f'{targetdir}/MRPC.tsv'

# !mkdir -p {targetdir}
print(f'Copying results from {fetch}')
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_mrpc.txt {targetfn}
# !sed -i 's/not_equivalent/0/g' {targetfn}
# !sed -i 's/equivalent/1/g' {targetfn}
# !wc -l {targetfn}

fetch = uncased.iloc[0]['fn']
targetdir = 'submission/matbert-base-uncased'
targetfn = f'{targetdir}/MRPC.tsv'

# !mkdir -p {targetdir}
print(f'Copying results from {fetch}')
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_mrpc.txt {targetfn}
# !sed -i 's/not_equivalent/0/g' {targetfn}
# !sed -i 's/equivalent/1/g' {targetfn}
# !wc -l {targetfn}
# Out:
# Copying results from mrpc_cased_bs4_epoch5
# 1726 submission/matbert-base-cased/MRPC.tsv
# Copying results from mrpc_uncased_bs8_epoch5
# 1726 submission/matbert-base-uncased/MRPC.tsv

# %% [markdown]
# # STSB ✅

# %%
import pandas
import glob

data = []
for fn in glob.glob('/global/cscratch1/sd/haoyan/glue_eval/stsb*/eval*.txt'):
    with open(fn) as f:
        contents = dict(map(lambda x: x.strip().split(' = '), filter(str.strip, f.readlines())))
        contents['fn'] = fn.split('/')[-2]
        data.append(contents)
d = pandas.DataFrame(data)

cased = d.loc[d.fn.apply(lambda x: '_cased_' in x)].sort_values(['eval_combined_score'], ascending=False)
display(cased)

uncased = d.loc[d.fn.apply(lambda x: '_uncased_' in x)].sort_values(['eval_combined_score'], ascending=False)
display(uncased)
# Out:
#             eval_loss        eval_pearson      eval_spearmanr  \
# 2  0.5838404893875122  0.8629836653853799  0.8596867206286944
# 6  0.6037165522575378  0.8566966651596025  0.8538775315714939
# 3  0.6135368347167969  0.8557106731172879  0.8520886547614537
# 4  0.6363101601600647   0.853101122842072  0.8503540576127898
#
#   eval_combined_score epoch                      fn
# 2  0.8613351930070372   5.0   stsb_cased_bs4_epoch5
# 6  0.8552870983655483   5.0  stsb_cased_bs16_epoch5
# 3  0.8538996639393708   5.0   stsb_cased_bs2_epoch5
# 4  0.8517275902274308   5.0   stsb_cased_bs8_epoch5
#             eval_loss        eval_pearson      eval_spearmanr  \
# 7  0.5566169023513794    0.86944567862605  0.8661786041066005
# 5  0.5569857358932495  0.8693818609337868  0.8649393630389657
# 0  0.5609749555587769  0.8688224987805058  0.8645091011765835
# 1   0.587877631187439  0.8605702279709921  0.8565109373010853
#
#   eval_combined_score epoch                        fn
# ...

# %%
fetch = cased.iloc[0]['fn']
targetdir = 'submission/matbert-base-cased'
targetfn = f'{targetdir}/STS-B.tsv'

# !mkdir -p {targetdir}
print(f'Copying results from {fetch}')
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_stsb.txt {targetfn}
# !wc -l {targetfn}

results = pandas.read_csv(targetfn, sep='\t')
results.prediction = results.prediction.apply(lambda x: '%.3f' % max(0, min(5, x)))
results.to_csv(targetfn, index=False, sep='\t')

fetch = uncased.iloc[0]['fn']
targetdir = 'submission/matbert-base-uncased'
targetfn = f'{targetdir}/STS-B.tsv'

# !mkdir -p {targetdir}
print(f'Copying results from {fetch}')
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_stsb.txt {targetfn}
# !wc -l {targetfn}

results = pandas.read_csv(targetfn, sep='\t')
results.prediction = results.prediction.apply(lambda x: '%.3f' % max(0, min(5, x)))
results.to_csv(targetfn, index=False, sep='\t')
# Out:
# Copying results from stsb_cased_bs4_epoch5
# 1380 submission/matbert-base-cased/STS-B.tsv
# Copying results from stsb_uncased_bs4_epoch5
# 1380 submission/matbert-base-uncased/STS-B.tsv

# %% [markdown]
# ## RTE ✅

# %%
import pandas
import glob

data = []
for fn in glob.glob('/global/cscratch1/sd/haoyan/glue_eval/rte*/eval*.txt'):
    with open(fn) as f:
        contents = dict(map(lambda x: x.strip().split(' = '), filter(str.strip, f.readlines())))
        contents['fn'] = fn.split('/')[-2]
        data.append(contents)
d = pandas.DataFrame(data)

cased = d.loc[d.fn.apply(lambda x: '_cased_' in x)].sort_values(['eval_accuracy'], ascending=False)
display(cased)

uncased = d.loc[d.fn.apply(lambda x: '_uncased_' in x)].sort_values(['eval_accuracy'], ascending=False)
display(uncased)
# Out:
#             eval_loss       eval_accuracy epoch                     fn
# 6  1.5294681787490845  0.6606498194945848   5.0   rte_cased_bs8_epoch5
# 1   1.093050241470337  0.6570397111913358   5.0   rte_cased_bs4_epoch5
# 3  0.7535557746887207  0.6462093862815884   5.0  rte_cased_bs16_epoch5
# 7  0.9805178642272949  0.6209386281588448   5.0   rte_cased_bs2_epoch5
#             eval_loss       eval_accuracy epoch                       fn
# 4  1.0635700225830078  0.6425992779783394   5.0  rte_uncased_bs16_epoch5
# 2  0.8032739758491516  0.6209386281588448   5.0   rte_uncased_bs8_epoch5
# 0  0.9940837621688843  0.5776173285198556   5.0   rte_uncased_bs2_epoch5
# 5  0.6926047801971436  0.5270758122743683   5.0   rte_uncased_bs4_epoch5

# %%
fetch = cased.iloc[0]['fn']
targetdir = 'submission/matbert-base-cased'
targetfn = f'{targetdir}/RTE.tsv'

# !mkdir -p {targetdir}
print(f'Copying results from {fetch}')
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_rte.txt {targetfn}
# !wc -l {targetfn}

fetch = uncased.iloc[0]['fn']
targetdir = 'submission/matbert-base-uncased'
targetfn = f'{targetdir}/RTE.tsv'

# !mkdir -p {targetdir}
print(f'Copying results from {fetch}')
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_rte.txt {targetfn}
# !wc -l {targetfn}
# Out:
# Copying results from rte_cased_bs8_epoch5
# 3001 submission/matbert-base-cased/RTE.tsv
# Copying results from rte_uncased_bs16_epoch5
# 3001 submission/matbert-base-uncased/RTE.tsv

# %% [markdown]
# ## QQP ✅

# %%
import pandas
import glob

data = []
for fn in glob.glob('/global/cscratch1/sd/haoyan/glue_eval/qqp*/eval*.txt'):
    with open(fn) as f:
        contents = dict(map(lambda x: x.strip().split(' = '), filter(str.strip, f.readlines())))
        contents['fn'] = fn.split('/')[-2]
        data.append(contents)
d = pandas.DataFrame(data)

cased = d.loc[d.fn.apply(lambda x: '_cased_' in x)].sort_values(['eval_combined_score'], ascending=False)
display(cased)

uncased = d.loc[d.fn.apply(lambda x: '_uncased_' in x)].sort_values(['eval_combined_score'], ascending=False)
display(uncased)
# Out:
#              eval_loss       eval_accuracy             eval_f1  \
# 0  0.36040589213371277  0.9018550581251545  0.8677333333333334
# 2   0.3611929714679718  0.8976997279248083  0.8631188774159386
#
#   eval_combined_score                     fn epoch
# 0   0.884794195729244  qqp_cased_bs16_epoch5   NaN
# 2  0.8804093026703734   qqp_cased_bs8_epoch5   5.0
#              eval_loss       eval_accuracy             eval_f1  \
# 3   0.4326559901237488  0.9030422953252535  0.8683680322364002
# 1  0.43782907724380493  0.9011377689834281  0.8665397842999767
#
#   eval_combined_score                       fn epoch
# 3  0.8857051637808269  qqp_uncased_bs16_epoch5   NaN
# 1  0.8838387766417024   qqp_uncased_bs8_epoch5   5.0

# %%
fetch = cased.iloc[0]['fn']
targetdir = 'submission/matbert-base-cased'
targetfn = f'{targetdir}/QQP.tsv'

# !mkdir -p {targetdir}
print(f'Copying results from {fetch}')
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_qqp.txt {targetfn}
# !sed -i 's/not_duplicate/0/g' {targetfn}
# !sed -i 's/duplicate/1/g' {targetfn}
# !wc -l {targetfn}

fetch = uncased.iloc[0]['fn']
targetdir = 'submission/matbert-base-uncased'
targetfn = f'{targetdir}/QQP.tsv'

# !mkdir -p {targetdir}
print(f'Copying results from {fetch}')
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_qqp.txt {targetfn}
# !sed -i 's/not_duplicate/0/g' {targetfn}
# !sed -i 's/duplicate/1/g' {targetfn}
# !wc -l {targetfn}
# Out:
# Copying results from qqp_cased_bs16_epoch5
# 390966 submission/matbert-base-cased/QQP.tsv
# Copying results from qqp_uncased_bs16_epoch5
# 390966 submission/matbert-base-uncased/QQP.tsv

# %% [markdown]
# ## SST2 ✅

# %%
import pandas
import glob

data = []
for fn in glob.glob('/global/cscratch1/sd/haoyan/glue_eval/sst2*/eval*.txt'):
    with open(fn) as f:
        contents = dict(map(lambda x: x.strip().split(' = '), filter(str.strip, f.readlines())))
        contents['fn'] = fn.split('/')[-2]
        data.append(contents)
d = pandas.DataFrame(data)

cased = d.loc[d.fn.apply(lambda x: '_cased_' in x)].sort_values(['eval_accuracy'], ascending=False)
display(cased)

uncased = d.loc[d.fn.apply(lambda x: '_uncased_' in x)].sort_values(['eval_accuracy'], ascending=False)
display(uncased)
# Out:
#             eval_loss       eval_accuracy epoch                      fn
# 0  0.4211183488368988  0.8956422018348624   5.0  sst2_cased_bs16_epoch5
# 1  0.5195742249488831  0.8899082568807339   5.0   sst2_cased_bs8_epoch5
# 4  0.3942393660545349  0.8784403669724771   5.0   sst2_cased_bs4_epoch5
# 5  0.7145008444786072  0.7259174311926605   5.0   sst2_cased_bs2_epoch5
#              eval_loss       eval_accuracy epoch                        fn
# 7  0.41584935784339905  0.8967889908256881   5.0  sst2_uncased_bs16_epoch5
# 2  0.48502084612846375  0.8956422018348624   5.0   sst2_uncased_bs8_epoch5
# 6    0.519001841545105  0.8853211009174312   5.0   sst2_uncased_bs4_epoch5
# 3   0.6235259771347046  0.8119266055045872   5.0   sst2_uncased_bs2_epoch5

# %%
fetch = cased.iloc[0]['fn']
targetdir = 'submission/matbert-base-cased'
targetfn = f'{targetdir}/SST-2.tsv'

# !mkdir -p {targetdir}
print(f'Copying results from {fetch}')
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_sst2.txt {targetfn}
# !sed -i 's/negative/0/g' {targetfn}
# !sed -i 's/positive/1/g' {targetfn}
# !wc -l {targetfn}

fetch = uncased.iloc[0]['fn']
targetdir = 'submission/matbert-base-uncased'
targetfn = f'{targetdir}/SST-2.tsv'

# !mkdir -p {targetdir}
print(f'Copying results from {fetch}')
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_sst2.txt {targetfn}
# !sed -i 's/negative/0/g' {targetfn}
# !sed -i 's/positive/1/g' {targetfn}
# !wc -l {targetfn}
# Out:
# Copying results from sst2_cased_bs16_epoch5
# 1822 submission/matbert-base-cased/SST-2.tsv
# Copying results from sst2_uncased_bs16_epoch5
# 1822 submission/matbert-base-uncased/SST-2.tsv

# %% [markdown]
# ## MNLI ✅

# %%
import pandas
import glob

data = []
for fn in glob.glob('/global/cscratch1/sd/haoyan/glue_eval/mnli*/eval_results_mnli.txt'):
    with open(fn) as f:
        contents = dict(map(lambda x: x.strip().split(' = '), filter(str.strip, f.readlines())))
        contents['fn'] = fn.split('/')[-2]
        data.append(contents)
d = pandas.DataFrame(data)

cased = d.loc[d.fn.apply(lambda x: '_cased_' in x)].sort_values(['eval_accuracy'], ascending=False)
display(cased)

uncased = d.loc[d.fn.apply(lambda x: '_uncased_' in x)].sort_values(['eval_accuracy'], ascending=False)
display(uncased)
# Out:
#             eval_loss       eval_accuracy                      fn epoch
# 2  0.6908169984817505  0.7952114111054508   mnli_cased_bs8_epoch5   5.0
# 1  0.5181633234024048  0.7944982170147733  mnli_cased_bs16_epoch5   NaN
#             eval_loss       eval_accuracy                        fn epoch
# 0  0.6502271294593811  0.8096790626591951  mnli_uncased_bs16_epoch5   NaN
# 3  0.6354188919067383  0.8025471217524197   mnli_uncased_bs8_epoch5   5.0

# %%
fetch = cased.iloc[0]['fn']
targetdir = 'submission/matbert-base-cased'

# !mkdir -p {targetdir}
print(f'Copying results from {fetch}')
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_mnli.txt {targetdir}/MNLI-m.tsv
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_mnli-mm.txt {targetdir}/MNLI-mm.tsv
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_mnli-ax.txt {targetdir}/AX.tsv
# !wc -l {targetdir}/MNLI-m.tsv
# !wc -l {targetdir}/MNLI-mm.tsv
# !wc -l {targetdir}/AX.tsv

fetch = uncased.iloc[0]['fn']
targetdir = 'submission/matbert-base-uncased'
targetfn = f'{targetdir}/MNLI-m.tsv'

# !mkdir -p {targetdir}
print(f'Copying results from {fetch}')
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_mnli.txt {targetdir}/MNLI-m.tsv
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_mnli-mm.txt {targetdir}/MNLI-mm.tsv
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_mnli-ax.txt {targetdir}/AX.tsv
# !wc -l {targetdir}/MNLI-m.tsv
# !wc -l {targetdir}/MNLI-mm.tsv
# !wc -l {targetdir}/AX.tsv
# Out:
# Copying results from mnli_cased_bs8_epoch5
# 9797 submission/matbert-base-cased/MNLI-m.tsv
# 9848 submission/matbert-base-cased/MNLI-mm.tsv
# 1105 submission/matbert-base-cased/AX.tsv
# Copying results from mnli_uncased_bs16_epoch5
# 9797 submission/matbert-base-uncased/MNLI-m.tsv
# 9848 submission/matbert-base-uncased/MNLI-mm.tsv
# 1105 submission/matbert-base-uncased/AX.tsv

# %% [markdown]
# ## QNLI

# %%
import pandas
import glob

data = []
for fn in glob.glob('/global/cscratch1/sd/haoyan/glue_eval/qnli*/eval*.txt'):
    with open(fn) as f:
        contents = dict(map(lambda x: x.strip().split(' = '), filter(str.strip, f.readlines())))
        contents['fn'] = fn.split('/')[-2]
        data.append(contents)
d = pandas.DataFrame(data)

cased = d.loc[d.fn.apply(lambda x: '_cased_' in x)].sort_values(['eval_accuracy'], ascending=False)
display(cased)

uncased = d.loc[d.fn.apply(lambda x: '_uncased_' in x)].sort_values(['eval_accuracy'], ascending=False)
display(uncased)
# Out:
#             eval_loss       eval_accuracy                      fn epoch
# 3  0.4999404847621918  0.8846787479406919  qnli_cased_bs16_epoch5   NaN
# 5  0.6937551498413086  0.8634449935932638   qnli_cased_bs8_epoch5   5.0
# 1  0.4709254205226898  0.8434925864909391   qnli_cased_bs4_epoch5   5.0
# 4  0.6933661699295044  0.5053999633900788   qnli_cased_bs2_epoch5   5.0
#              eval_loss       eval_accuracy                        fn epoch
# 0   0.3032214641571045  0.8812008054182684  qnli_uncased_bs16_epoch5   NaN
# 2  0.36691951751708984  0.8564891085484166   qnli_uncased_bs4_epoch5   5.0
# 6    0.694560170173645  0.5053999633900788   qnli_uncased_bs8_epoch5   5.0

# %%
fetch = cased.iloc[0]['fn']
targetdir = 'submission/matbert-base-cased'
targetfn = f'{targetdir}/QNLI.tsv'

# !mkdir -p {targetdir}
print(f'Copying results from {fetch}')
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_qnli.txt {targetfn}
# !wc -l {targetfn}

fetch = uncased.iloc[0]['fn']
targetdir = 'submission/matbert-base-uncased'
targetfn = f'{targetdir}/QNLI.tsv'

# !mkdir -p {targetdir}
print(f'Copying results from {fetch}')
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_qnli.txt {targetfn}
# !wc -l {targetfn}
# Out:
# Copying results from qnli_cased_bs16_epoch5
# 5464 submission/matbert-base-cased/QNLI.tsv
# Copying results from qnli_uncased_bs16_epoch5
# 5464 submission/matbert-base-uncased/QNLI.tsv

# %% [markdown]
# ## WNLI 🤔️

# %%
import pandas
import glob

data = []
for fn in glob.glob('/global/cscratch1/sd/haoyan/glue_eval/wnli*/eval*.txt'):
    with open(fn) as f:
        contents = dict(map(lambda x: x.strip().split(' = '), filter(str.strip, f.readlines())))
        contents['fn'] = fn.split('/')[-2]
        data.append(contents)
d = pandas.DataFrame(data)

cased = d.loc[d.fn.apply(lambda x: '_cased_' in x)].sort_values(['eval_accuracy'], ascending=False)
display(cased)

uncased = d.loc[d.fn.apply(lambda x: '_uncased_' in x)].sort_values(['eval_accuracy'], ascending=False)
display(uncased)
# Out:
#             eval_loss        eval_accuracy epoch                       fn
# 0  0.7810431718826294  0.18309859154929578  10.0  wnli_cased_bs64_epoch10
# 1   0.759276807308197  0.14084507042253522   8.0   wnli_cased_bs64_epoch8
#             eval_loss       eval_accuracy epoch                         fn
# 2  0.6906067728996277  0.5633802816901409  10.0  wnli_uncased_bs64_epoch10

# %%
fetch = cased.iloc[0]['fn']
targetdir = 'submission/matbert-base-cased'
targetfn = f'{targetdir}/WNLI.tsv'

# !mkdir -p {targetdir}
print(f'Copying results from {fetch}')
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_wnli.txt {targetfn}
# !sed -i 's/not_entailment/0/g' {targetfn}
# !sed -i 's/entailment/1/g' {targetfn}
# !wc -l {targetfn}

fetch = uncased.iloc[0]['fn']
targetdir = 'submission/matbert-base-uncased'
targetfn = f'{targetdir}/WNLI.tsv'

# !mkdir -p {targetdir}
print(f'Copying results from {fetch}')
# !cp $$SCRATCH/glue_eval/{fetch}/test_results_wnli.txt {targetfn}
# !sed -i 's/not_entailment/0/g' {targetfn}
# !sed -i 's/entailment/1/g' {targetfn}
# !wc -l {targetfn}
# Out:
# Copying results from wnli_cased_bs64_epoch10
# 147 submission/matbert-base-cased/WNLI.tsv
# Copying results from wnli_uncased_bs64_epoch10
# 147 submission/matbert-base-uncased/WNLI.tsv

# %% [markdown]
# ## Total

# %%
# !wc -l submission/matbert-base-cased/*
# !wc -l submission/matbert-base-uncased/*
# Out:
#    1105 submission/matbert-base-cased/AX.tsv
#    1064 submission/matbert-base-cased/CoLA.tsv
#    9797 submission/matbert-base-cased/MNLI-m.tsv
#    9848 submission/matbert-base-cased/MNLI-mm.tsv
#    1726 submission/matbert-base-cased/MRPC.tsv
#    5464 submission/matbert-base-cased/QNLI.tsv
#  390966 submission/matbert-base-cased/QQP.tsv
#    3001 submission/matbert-base-cased/RTE.tsv
#    1822 submission/matbert-base-cased/SST-2.tsv
#    1380 submission/matbert-base-cased/STS-B.tsv
#     147 submission/matbert-base-cased/WNLI.tsv
#  426320 total
#    1105 submission/matbert-base-uncased/AX.tsv
#    1064 submission/matbert-base-uncased/CoLA.tsv
#    9797 submission/matbert-base-uncased/MNLI-m.tsv
#    9848 submission/matbert-base-uncased/MNLI-mm.tsv
#    1726 submission/matbert-base-uncased/MRPC.tsv
#    5464 submission/matbert-base-uncased/QNLI.tsv
#  390966 submission/matbert-base-uncased/QQP.tsv
#    3001 submission/matbert-base-uncased/RTE.tsv
# ...
